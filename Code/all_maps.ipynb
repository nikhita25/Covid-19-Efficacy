# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import folium 
import mapclassify

# %%
Data=pd.read_csv('../Data/covid_data_merged')

# %%
Data=Data.drop(columns=['Protection from Ancestral var - Severe Disease','Protection from Ancestral var - Infection','Protection from Beta var - Severe Disease','Protection from Beta var - Infection','Protection from Gamma var - Severe Disease','Protection from Gamma var - Infection'])

# %%
#Data=Data.drop(labels= 'European Union', axis=0)
new_dt=Data[Data.Country != 'European Union']

# %%
new_dt
# Out:
#          Country        Date Vaccine_Manufacturer  Total_Vaccinations  \
# 0      Argentina  12/29/2020   Oxford/AstraZeneca                   1
# 1      Argentina  12/29/2020    Sinopharm/Beijing                   1
# 2      Argentina  12/29/2020            Sputnik V               20488
# 3      Argentina  12/30/2020            Sputnik V               40590
# 4      Argentina  12/31/2020            Sputnik V               43396
# ...          ...         ...                  ...                 ...
# 41545    Uruguay  10/12/2022      Pfizer/BioNTech             2556144
# 41546    Uruguay  10/13/2022      Pfizer/BioNTech             2556166
# 41547    Uruguay  10/14/2022      Pfizer/BioNTech             2556194
# 41548    Uruguay  10/15/2022      Pfizer/BioNTech             2556197
# 41549    Uruguay  10/17/2022      Pfizer/BioNTech             2556226
#
#        Alpha Severe Disease  Alpha Infection  Beta Severe Disease  \
# ...

# %%
new_dt.groupby('Country')['Total_Vaccinations'].max();

# %%
new_dt['Vaccine_Manufacturer'].unique()
# Out:
# array(['Oxford/AstraZeneca', 'Sinopharm/Beijing', 'Sputnik V',
#        'Pfizer/BioNTech', 'CanSino', 'Moderna', 'Johnson&Johnson',
#        'Novavax', 'Valneva', 'Medicago', 'Sinovac', 'Covaxin',
#        'SKYCovione'], dtype=object)

# %%
Oxford_AstraZeneca=new_dt[new_dt['Vaccine_Manufacturer']=='Oxford/AstraZeneca']

# %%
maxi=pd.DataFrame(Oxford_AstraZeneca.groupby('Country')['Total_Vaccinations'].max())

# %%
maxi.reset_index(inplace=True)

# %%
# Read the geopandas dataset
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
tables=world.merge(maxi,how='left',left_on=['name'],right_on=['Country'])

# %%
tables=tables.dropna(subset=['Total_Vaccinations'])

# %%
# Create a map
my_map = folium.Map()

# %%
folium.Choropleth(
    geo_data=tables,
    name='choropleth',
    data=tables,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Oxford/AstraZeneca Vaccine'
).add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
Sinopharm_Beijing=new_dt[new_dt['Vaccine_Manufacturer']=='Sinopharm/Beijing']

# %%
maxi_1=pd.DataFrame(Sinopharm_Beijing.groupby(['Country'])['Total_Vaccinations'].max())
maxi_1;

# %%
maxi_1.reset_index(inplace=True)

# %%
tables1=world.merge(maxi_1,how='left',left_on=['name'],right_on=['Country'])
tables1;

# %%
tables1=tables1.dropna(subset=['Total_Vaccinations'])

# %%
tables1;

# %%
my_map_1= folium.Map()

# %%
folium.Choropleth(
    geo_data=tables1,
    name='choropleth',
    data=tables1,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='Blues',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Sinopharm/Beijing Vaccine'
).add_to(my_map_1)
#my_map.save('Sinopharm/Beijing.html')

# %%
my_map_1.save('Sinopharm_Beijin.html')

# %%
my_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
Sputnik_V=new_dt[new_dt['Vaccine_Manufacturer']=='Sputnik V']

# %%
maxi_2=pd.DataFrame(Sputnik_V.groupby(['Country'])['Total_Vaccinations'].max())

# %%
maxi_2.reset_index(inplace=True)

# %%
tables2=world.merge(maxi_2,how='left',left_on=['name'],right_on=['Country'])

# %%
tables2=tables2.dropna(subset=['Total_Vaccinations'])

# %%
my_map_2= folium.Map()

# %%
folium.Choropleth(
    geo_data=tables2,
    name='choropleth',
    data=tables2,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='BrBG',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Sputnik V Vaccine'
).add_to(my_map_2)
#my_map.save('Sinopharm/Beijing.html')

# %%
my_map_2;

# %%
my_map_2.save('Sputnik_V.html')

# %%
Pfizer_BioNTech=new_dt[new_dt['Vaccine_Manufacturer']=='Pfizer/BioNTech']

# %%
maxi_3=pd.DataFrame(Pfizer_BioNTech.groupby(['Country'])['Total_Vaccinations'].max())

# %%
maxi_3.reset_index(inplace=True)

# %%
tables3=world.merge(maxi_3,how='left',left_on=['name'],right_on=['Country'])

# %%
tables3=tables3.dropna(subset=['Total_Vaccinations'])

# %%
my_map_3= folium.Map()

# %%
folium.Choropleth(
    geo_data=tables3,
    name='choropleth',
    data=tables3,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='PRGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Pfizer/BioNTech Vaccine'
).add_to(my_map_3)
#my_map.save('Sinopharm/Beijing.html')

# %%
my_map_3;

# %%
my_map_3.save('Pfizer_BioNTech.html')

# %%
new_dt['Vaccine_Manufacturer'].unique()
# Out:
# array(['Oxford/AstraZeneca', 'Sinopharm/Beijing', 'Sputnik V',
#        'Pfizer/BioNTech', 'CanSino', 'Moderna', 'Johnson&Johnson',
#        'Novavax', 'Valneva', 'Medicago', 'Sinovac', 'Covaxin',
#        'SKYCovione'], dtype=object)

# %%
CanSino=new_dt[new_dt['Vaccine_Manufacturer']=='CanSino']

# %%
maxi_4=pd.DataFrame(CanSino.groupby(['Country'])['Total_Vaccinations'].max())

# %%
maxi_4.reset_index(inplace=True)

# %%
tables4=world.merge(maxi_4,how='left',left_on=['name'],right_on=['Country'])

# %%
tables4=tables4.dropna(subset=['Total_Vaccinations'])

# %%
my_map_4= folium.Map()

# %%
folium.Choropleth(
    geo_data=tables4,
    name='choropleth',
    data=tables4,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='PuOr',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='CanSino Vaccine'
).add_to(my_map_4)
#my_map.save('Sinopharm/Beijing.html')

# %%
my_map_4;

# %%
my_map_4.save('CanSino.html')

# %%
Moderna=new_dt[new_dt['Vaccine_Manufacturer']=='Moderna']

# %%
maxi_5=pd.DataFrame(Moderna.groupby(['Country'])['Total_Vaccinations'].max())

# %%
maxi_5.reset_index(inplace=True)

# %%
tables5=world.merge(maxi_5,how='left',left_on=['name'],right_on=['Country'])

# %%
tables5=tables5.dropna(subset=['Total_Vaccinations'])

# %%
my_map_5= folium.Map()

# %%
folium.Choropleth(
    geo_data=tables5,
    name='choropleth',
    data=tables5,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='RdBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Moderna Vaccine'
).add_to(my_map_5)
#my_map.save('Sinopharm/Beijing.html')

# %%
my_map_5;

# %%
my_map_5.save('Moderna.html')

# %%
Johnson_Johnson=new_dt[new_dt['Vaccine_Manufacturer']=='Johnson&Johnson']

# %%
maxi_6=pd.DataFrame(Johnson_Johnson.groupby(['Country'])['Total_Vaccinations'].max())

# %%
maxi_6.reset_index(inplace=True)

# %%
tables6=world.merge(maxi_6,how='left',left_on=['name'],right_on=['Country'])

# %%
tables6=tables6.dropna(subset=['Total_Vaccinations'])

# %%
my_map_6= folium.Map()

# %%
folium.Choropleth(
    geo_data=tables6,
    name='choropleth',
    data=tables6,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='Spectral',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Johnson&Johnson Vaccine'
).add_to(my_map_6)
my_map_6.save('Johnson$Johnson.html')

# %%
new_dt['Vaccine_Manufacturer'].unique()
# Out:
# array(['Oxford/AstraZeneca', 'Sinopharm/Beijing', 'Sputnik V',
#        'Pfizer/BioNTech', 'CanSino', 'Moderna', 'Johnson&Johnson',
#        'Novavax', 'Valneva', 'Medicago', 'Sinovac', 'Covaxin',
#        'SKYCovione'], dtype=object)

# %%
Novavax=new_dt[new_dt['Vaccine_Manufacturer']=='Novavax'];
maxi_7=pd.DataFrame(Novavax.groupby(['Country'])['Total_Vaccinations'].max());
maxi_7.reset_index(inplace=True);
tables7=world.merge(maxi_7,how='left',left_on=['name'],right_on=['Country']);
tables7=tables7.dropna(subset=['Total_Vaccinations']);
my_map_7= folium.Map();
folium.Choropleth(
    geo_data=tables7,
    name='choropleth',
    data=tables7,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='BuGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Novavax Vaccine'
).add_to(my_map_7)
my_map_7.save('Novavax.html')

# %%
Valneva=new_dt[new_dt['Vaccine_Manufacturer']=='Valneva'];
maxi_8=pd.DataFrame(Valneva.groupby(['Country'])['Total_Vaccinations'].max());
maxi_8.reset_index(inplace=True);
tables8=world.merge(maxi_8,how='left',left_on=['name'],right_on=['Country']);
tables8=tables8.dropna(subset=['Total_Vaccinations']);
my_map_8= folium.Map();
folium.Choropleth(
    geo_data=tables8,
    name='choropleth',
    data=tables8,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='Dark2',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Valneva Vaccine'
).add_to(my_map_8)
my_map_8.save('Valneva.html')

# %%
Medicago=new_dt[new_dt['Vaccine_Manufacturer']=='Medicago'];
maxi_9=pd.DataFrame(Medicago.groupby(['Country'])['Total_Vaccinations'].max());
maxi_9.reset_index(inplace=True);
tables9=world.merge(maxi_9,how='left',left_on=['name'],right_on=['Country']);
tables9=tables9.dropna(subset=['Total_Vaccinations']);
my_map_9= folium.Map();
folium.Choropleth(
    geo_data=tables9,
    name='choropleth',
    data=tables9,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='Set3',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Medicago Vaccine'
).add_to(my_map_9)
my_map_9.save('Medicago.html')

# %%
Sinovac=new_dt[new_dt['Vaccine_Manufacturer']=='Sinovac'];
maxi_10=pd.DataFrame(Sinovac.groupby(['Country'])['Total_Vaccinations'].max());
maxi_10.reset_index(inplace=True);
tables10=world.merge(maxi_10,how='left',left_on=['name'],right_on=['Country']);
tables10=tables10.dropna(subset=['Total_Vaccinations']);
my_map_10= folium.Map();
folium.Choropleth(
    geo_data=tables10,
    name='choropleth',
    data=tables10,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='Set3',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Sinovac Vaccine'
).add_to(my_map_10)
my_map_10.save('Sinovac.html')

# %%
Covaxin=new_dt[new_dt['Vaccine_Manufacturer']=='Covaxin'];
maxi_11=pd.DataFrame(Covaxin.groupby(['Country'])['Total_Vaccinations'].max());
maxi_11.reset_index(inplace=True);
tables11=world.merge(maxi_11,how='left',left_on=['name'],right_on=['Country']);
tables11=tables11.dropna(subset=['Total_Vaccinations']);
my_map_11= folium.Map();
folium.Choropleth(
    geo_data=tables11,
    name='choropleth',
    data=tables11,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='Set3',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Covaxin Vaccine'
).add_to(my_map_11)
my_map_11.save('Covaxin.html')

# %%
SKYCovione=new_dt[new_dt['Vaccine_Manufacturer']=='SKYCovione'];
maxi_12=pd.DataFrame(SKYCovione.groupby(['Country'])['Total_Vaccinations'].max());
maxi_12.reset_index(inplace=True);
tables12=world.merge(maxi_11,how='left',left_on=['name'],right_on=['Country']);
tables12=tables11.dropna(subset=['Total_Vaccinations']);
my_map_12= folium.Map();
folium.Choropleth(
    geo_data=tables12,
    name='choropleth',
    data=tables12,
    columns=['Country', 'Total_Vaccinations'],
    key_on='feature.properties.name',
    fill_color='Set3',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='SKYCovione Vaccine'
).add_to(my_map_12)
my_map_12.save('SKYCovione.html')

# %%
folium.Choropleth?
